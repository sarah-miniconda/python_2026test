# %%
# jupyternotebook 老師用終端機開
# cd /Users/sarahhuang/Documents/Github/python_2026test
# uv add jupyter
# uv run jupyter lab

# %%
# 建立工廠 
# 自訂的類別（空殼公司）
class Person:
    pass

# %%
p1 = Person()
type(p1)
