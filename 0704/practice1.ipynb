# %%
# jupyternotebook 老師用終端機開
# cd /Users/sarahhuang/Documents/Github/python_2026test
# uv add jupyter
# uv run jupyter lab

# %%
# 建立工廠 
# 自訂的類別（空殼公司）
class Person:
    def __init__(self): #自訂的初始化
        print("初始化：新的人")

# %%
p1 = Person()
type(p1)
# Out:
# 初始化：新的人
# __main__.Person

# %%
class Person:
    pass

# %%
class Person:
    def __init__(self,name): #建立一個attribute
        self.name = name


    # 建立實體method
    def introduce (self):
        print(f"Hello, 我的名字是{self.name}")

# %%
P2 = Person("Robert")  #帶入attribute
P2.name
print(P2. name)
P2. introduce()
# Out:
# Robert
# Hello, 我的名字是Robert

# %%
P3 = Person("Sue")
P3.name
# Out:
# 'Sue'
