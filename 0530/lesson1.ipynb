# %%
# list
scores = [89, 92, 76, 91, 77]
# 運算式
print(scores)
print(scores[0])
print(scores[1])
print(scores[2])
print(scores[3])
print(scores[4])

scores[0] = 100
print(scores)
# Out:
# [89, 92, 76, 91, 77]
# 89
# 92
# 76
# 91
# 77
# [100, 92, 76, 91, 77]

# %%
# tuple , 建立後不可改 ,暫時儲存
scores1 = (89, 92, 76, 91, 77)
print(scores1)

print(scores1[0])
print(scores1[1])
print(scores1[2])
print(scores1[3])
print(scores1[4])
# Out:
# (89, 92, 76, 91, 77)
# 89
# 92
# 76
# 91
# 77

# %%
# subscript >>> scores[0]  裡面の中括弧

# %%
# dictionary
students = {'chinese':89, 'english':94, 'math':95, 'history':92, 'discover':95}
students = {
    'chinese':89, 
    'english':94, 
    'math':95, 
    'history':92, 
    'discover':95}
print(students)
print(students['chinese'])
print(students['english'])
print(students['math'])
print(students['history'])
print(students['discover'])
# Out:
# {'chinese': 89, 'english': 94, 'math': 95, 'history': 92, 'discover': 95}
# 89
# 94
# 95
# 92
# 95

# %%
for i in scores1:
    print(i)
#  for in 後面可以放串列資料，map資料
# Out:
# 89
# 92
# 76
# 91
# 77

# %%
for key in students:
    print(key)
    print(students[key])
# Out:
# chinese
# 89
# english
# 94
# math
# 95
# history
# 92
# discover
# 95

# %%
for key in students:
    print(students[key])
# Out:
# 89
# 94
# 95
# 92
# 95
